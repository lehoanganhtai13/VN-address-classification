# %%
from address_segmentation import addressSegmentation
import time
import json
import re

# %%
dataset = open('./../dataset/vn_address_dataset.txt', encoding="utf8").readlines()
segmenter = addressSegmentation(dataset)

# %%
test_file = open('./../tests/test_cases/public.json')
test_data = json.load(test_file)

# %%
str(type(test_data[0]))
# Out:
# "<class 'dict'>"

# %%
pass_count = 0
for data in test_data:
    address = data['text']
    start = time.time()
    result = segmenter.segment(address)
    stop = time.time()

    pass_value = False
    if result['province'] == data['result']['province'] and result['district'] == data['result']['district'] and result['ward'] == data['result']['ward']:
        pass_value = True
    # print('Pass value:', pass_value)
    pass_time = True if ((stop - start) < 0.1) else False
    # print('Pass time:', pass_value)
    if pass_value == True and pass_time == True:
        pass_count += 1
    else:   
        print(address)
        print('result:',result)
        print('answer',data['result'])
        print('')

print('Total pass:', pass_count)
# Out:
# 357/28,Ng-T- Thuật,P1,Q3,TP.HồChíMinh.
# result: {'province': 'Hồ Chí Minh', 'district': '3', 'ward': '1'}
# answer {'province': 'Hồ Chí Minh', 'district': '', 'ward': ''}
#
# Phú Lộc Phú Thạnh, Phú Tân, An Giang
# result: {'province': 'An Giang', 'district': 'Phú Tân', 'ward': 'Phú Thành'}
# answer {'province': 'An Giang', 'district': 'Phú Tân', 'ward': 'Phú Thạnh'}
#
# Tiểu khu 3, thị trấn Ba Hàng, huyện Phổ Yên, tỉnh Thái Nguyên.
# result: {'province': 'Thái Nguyên', 'district': 'Phổ Yên', 'ward': 'Ba Hàng'}
# answer {'province': '', 'district': '', 'ward': ''}
#
# Hoằng Anh Thành phố Thanh Hóa, Thanh Hóa
# result: {'province': 'Thanh Hóa', 'district': 'Thanh Hóa', 'ward': ''}
# answer {'province': 'Thanh Hóa', 'district': 'Thanh Hóa', 'ward': 'Hoằng Anh'}
#
# 154/4/81 Nguyễn - Phúc Chu, P15, TB, TP. Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': '5', 'ward': '1'}
# answer {'province': '', 'district': '', 'ward': ''}
#
# Thái Hòa Huyện Thái Thụy, Thái Bình
# result: {'province': 'Thái Bình', 'district': 'Thái Thụy', 'ward': ''}
# answer {'province': 'Thái Bình', 'district': 'Thái Thụy', 'ward': 'Thái Hòa'}
#
# 489/24A/18 Huỳnh Văn Bánh Phường 13, Phú Nhuận, TP. Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': 'Phú Nhuận', 'ward': '3'}
# answer {'province': 'Hồ Chí Minh', 'district': 'Phú Nhuận', 'ward': '13'}
#
# 285 B/1A Bình Gĩa Phường 8,Vũng Tàu,Bà Rịa - Vũng Tàu
# result: {'province': 'Bà Rịa Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '8'}
# answer {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '8'}
#
# KP Phước Trung Thị trấn Đất Đỏ, Đất Đỏ, Bà Rịa - Vũng Tàu
# result: {'province': 'Bà Rịa Vũng Tàu', 'district': 'Đất Đỏ', 'ward': 'Đất Đỏ'}
# answer {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Đất Đỏ', 'ward': 'Đất Đỏ'}
#
# 55/30 Nguyễn - Thượng Hiền,P5,BT, TP. Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': '5', 'ward': ''}
# answer {'province': 'Hồ Chí Minh', 'district': 'Bình Thạnh', 'ward': '5'}
#
# 290 Tùng Thiện- Vương,P.13, Quận 8, TP. Hồ Chí Minh.
# result: {'province': 'Hồ Chí Minh', 'district': '8', 'ward': '3'}
# answer {'province': 'Hồ Chí Minh', 'district': '8', 'ward': '13'}
#
# Khu phố Nam Tân, TT Thuận Nam, Hàm Thuận Bắc, Bình Thuận.
# result: {'province': 'Bình Thuận', 'district': 'Hàm Thuận Bắc', 'ward': ''}
# answer {'province': '', 'district': '', 'ward': ''}
#
# Xã Nguyên Bình Huyện Tĩnh Gia, Thanh Hoá
# result: {'province': 'Thanh Hóa', 'district': 'Nghi Sơn', 'ward': 'Nguyên Bình'}
# answer {'province': 'Thanh Hóa', 'district': 'Tĩnh Gia', 'ward': 'Nguyên Bình'}
#
# Hoằng Minh, Hoằng Hóa Thanh Hóa
# result: {'province': 'Thanh Hóa', 'district': 'Hoằng Hóa', 'ward': ''}
# answer {'province': 'Thanh Hóa', 'district': 'Hoằng Hóa', 'ward': 'Hoằng Minh'}
#
# Liên Bình, Hải Bình Tĩnh Gia, Thanh Hóa
# result: {'province': 'Thanh Hóa', 'district': 'Nghi Sơn', 'ward': 'Hải Bình'}
# answer {'province': 'Thanh Hóa', 'district': 'Tĩnh Gia', 'ward': 'Hải Bình'}
#
# - Khu B Chu Hoà, Việt HhiPhú Thọ
# result: {'province': 'Phú Thọ', 'district': 'Việt Trì', 'ward': 'Chu Hóa'}
# answer {'province': '', 'district': '', 'ward': ''}
#
# A:12A.21BlockA C/c BCA,P.AnKhánh,TP.Thủ Đức, TP. HCM
# result: {'province': 'Hồ Chí Minh', 'district': 'Thủ Đức', 'ward': 'An Khánh'}
# answer {'province': 'Hồ Chí Minh', 'district': 'Thủ Đức', 'ward': ''}
#
# L10C12 Hẻm 90, Ng, Bỉnh Khiêm, TP. Rạch Giá, Kiên Giang
# result: {'province': 'Kiên Giang', 'district': 'Rạch Giá', 'ward': ''}
# answer {'province': 'Kiên Giang', 'district': '', 'ward': ''}
#
# thôn 2 Suối Rao, Châu Đức, Bà Rịa - Vũng Tàu
# result: {'province': 'Bà Rịa Vũng Tàu', 'district': 'Châu Đức', 'ward': 'Suối Rao'}
# answer {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Châu Đức', 'ward': 'Suối Rao'}
#
# 14.5 Block A2, The Mansion, ĐS 7,KDC 13E,Ấp 5,PP,BC, TP.HCM
# result: {'province': 'Hồ Chí Minh', 'district': '5', 'ward': '3'}
# answer {'province': 'Hồ Chí Minh', 'district': '', 'ward': ''}
#
# 31B Sư Vạn Hạnh, Phường 3 Quận 10, TP. Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': '10', 'ward': ''}
# answer {'province': 'Hồ Chí Minh', 'district': '10', 'ward': '3'}
#
# 191A Nguyễn Thị Định An Phú, Quận 2, Tp Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': 'Gò Vấp', 'ward': '1'}
# answer {'province': 'Hồ Chí Minh', 'district': '2', 'ward': 'An Phú'}
#
# Số 1410 Đường 30/4, Phường 12, Thành phố Vũng Tàu, Bà Rịa - Vũng Tàu.
# result: {'province': 'Bà Rịa Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '2'}
# answer {'province': 'Bà Rịa - Vũng Tàu', 'district': 'Vũng Tàu', 'ward': '12'}
#
# F2B PhanVănTr P.5,GV,TP.Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': '5', 'ward': '2'}
# answer {'province': 'Hồ Chí Minh', 'district': '', 'ward': ''}
#
# 7/3/4/16 Thành Thái Phường 14, Quận 10, TP. Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': '10', 'ward': '4'}
# answer {'province': 'Hồ Chí Minh', 'district': '10', 'ward': '14'}
#
# 820/12 Hậu Giang, Phường 12 Quận 6, TP. Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': '6', 'ward': '2'}
# answer {'province': 'Hồ Chí Minh', 'district': '6', 'ward': '12'}
#
# Liên Minh,,TỉnhThái Nguyên
# result: {'province': 'Thái Nguyên', 'district': 'Võ Nhai', 'ward': 'Liên Minh'}
# answer {'district': '', 'ward': 'Liên Minh', 'province': 'Thái Nguyên'}
#
#  Chợ Chu, , T Thái Nguyên
# result: {'province': 'Thái Nguyên', 'district': 'Định Hóa', 'ward': 'Chợ Chu'}
# answer {'district': '', 'ward': 'Chợ Chu', 'province': 'Thái Nguyên'}
#
# Hải Ba  Hải Lăng
# result: {'province': 'Quảng Trị', 'district': 'Hải Lăng', 'ward': 'Hải Ba'}
# answer {'district': 'Hải Lăng', 'ward': 'Hải Ba', 'province': ''}
#
# Phường Phú Lợi  TBình Dương
# result: {'province': 'Bình Dương', 'district': 'Thủ Dầu Một', 'ward': 'Phú Lợi'}
# answer {'district': '', 'ward': 'Phú Lợi', 'province': 'Bình Dương'}
#
#  Bình Hiệp,H.Bình Sơn,TỉnhQuảng Ngãi
# result: {'province': 'Quảng Ngãi', 'district': 'Sơn Tịnh', 'ward': ''}
# answer {'district': 'Bình Sơn', 'ward': 'Bình Hiệp', 'province': 'Quảng Ngãi'}
#
# X.Thài Phìn Tủng, Huyện ĐồGg Van,  Hà Gxiang
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': 'Đồng Văn', 'ward': 'Thài Phìn Tủng', 'province': 'Hà Giang'}
#
# XãBù Gia Mập,,T Bình Phước
# result: {'province': 'Bình Phước', 'district': 'Bù Gia Mập', 'ward': ''}
# answer {'district': '', 'ward': 'Bù Gia Mập', 'province': 'Bình Phước'}
#
# Xã Mỹ Lương Yên Lập
# result: {'province': 'Phú Thọ', 'district': 'Yên Lập', 'ward': 'Mỹ Lương'}
# answer {'district': 'Yên Lập', 'ward': 'Mỹ Lương', 'province': ''}
#
# ,H.Nqm Đàn, nghệ An
# result: {'province': 'Nghệ An', 'district': '', 'ward': ''}
# answer {'district': 'Nam Đàn', 'ward': '', 'province': 'Nghệ An'}
#
# Xã La Dêê  Quảng Nam
# result: {'province': 'Quảng Nam', 'district': 'Nam Giang', 'ward': 'La Dêê'}
# answer {'district': '', 'ward': 'La Dêê', 'province': 'Quảng Nam'}
#
# XTân Thạnh, hAn Minh
# result: {'province': 'Hải Dương', 'district': 'Thanh Hà', 'ward': ''}
# answer {'district': 'An Minh', 'ward': 'Tân Thạnh', 'province': ''}
#
# X.UThạnh Lợi  TỉnhLong An
# result: {'province': 'Long An', 'district': 'Bến Lức', 'ward': 'Thạnh Lợi'}
# answer {'district': '', 'ward': 'Thạnh Lợi', 'province': 'Long An'}
#
#  Minh Tân,h.Lưng Tai,
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': 'Lương Tài', 'ward': 'Minh Tân', 'province': ''}
#
# XãQuỳn1 Lâm, H. Quỳnh Phụ,  Thai Bình
# result: {'province': 'Thái Bình', 'district': 'Quỳnh Phụ', 'ward': ''}
# answer {'district': 'Quỳnh Phụ', 'ward': 'Quỳnh Lâm', 'province': 'Thái Bình'}
#
# X.Nà Tấu, , T.Điện Biên
# result: {'province': 'Điện Biên', 'district': 'Điện Biên Phủ', 'ward': 'Nà Tấu'}
# answer {'district': '', 'ward': 'Nà Tấu', 'province': 'Điện Biên'}
#
# Sơn Thủy T Quảng Bình
# result: {'province': 'Quảng Bình', 'district': 'Lệ Thủy', 'ward': 'Sơn Thủy'}
# answer {'district': '', 'ward': 'Sơn Thủy', 'province': 'Quảng Bình'}
#
# Xan Tiến, H. An Lão,
# result: {'province': 'Hải Phòng', 'district': 'An Lão', 'ward': 'An Tiến'}
# answer {'district': 'An Lão', 'ward': 'An Tiến', 'province': ''}
#
# X. HoDng Quỳ,,9hanh Hóa
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Hoằng Quỳ', 'province': 'Thanh Hóa'}
#
# XãBình Chau,  Bình Sơn, Tỉnh Quảng Ngãi
# result: {'province': 'Quảng Ngãi', 'district': 'Sơn Tịnh', 'ward': ''}
# answer {'district': 'Bình Sơn', 'ward': 'Bình Châu', 'province': 'Quảng Ngãi'}
#
# X.Tân Tiến,H.Đồng Phú,
# result: {'province': 'Bình Phước', 'district': 'Đồng Phú', 'ward': 'Tân Tiến'}
# answer {'district': 'Đồng Phú', 'ward': 'Tân Tiến', 'province': ''}
#
# FHim Lam   Điện Biê
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Him Lam', 'province': 'Điện Biên'}
#
#  BảIn Sen H Mường Khương T5Lào Cai
# result: {'province': 'Lào Cai', 'district': 'Mường Khương', 'ward': ''}
# answer {'district': 'Mường Khương', 'ward': 'Bản Sen', 'province': 'Lào Cai'}
#
# XãV Ninh, Kiên Xương,
# result: {'province': 'Thái Bình', 'district': 'Kiến Xương', 'ward': ''}
# answer {'district': 'Kiến Xương', 'ward': 'Vũ Ninh', 'province': ''}
#
# X. Trà DVưong Bắc Trà My TQuảg Nam
# result: {'province': 'Quảng Nam', 'district': 'Bắc Trà My', 'ward': ''}
# answer {'district': 'Bắc Trà My', 'ward': 'Trà Dương', 'province': 'Quảng Nam'}
#
# X.Thiết Kế,H.Bá Thước,
# result: {'province': 'Thanh Hóa', 'district': 'Bá Thước', 'ward': 'Thiết Kế'}
# answer {'district': 'Bá Thước', 'ward': 'Thiết Kế', 'province': ''}
#
# X Quỳnh Nuyên,,T. Thái Bình
# result: {'province': 'Thái Bình', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Quỳnh Nguyên', 'province': 'Thái Bình'}
#
# XVnh Hung, , T.Thanh Hóa
# result: {'province': 'Thanh Hóa', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Vĩnh Hùng', 'province': 'Thanh Hóa'}
#
# X.Tăng Thanh, H Yên Thành,
# result: {'province': 'Nghệ An', 'district': 'Yên Thành', 'ward': 'Tăng Thành'}
# answer {'district': 'Yên Thành', 'ward': 'Tăng Thành', 'province': ''}
#
# XãTrung Lập,  Vĩnh Bảo,7
# result: {'province': 'Hải Phòng', 'district': 'Vĩnh Bảo', 'ward': 'Trung Lập'}
# answer {'district': 'Vĩnh Bảo', 'ward': 'Trung Lập', 'province': ''}
#
# Phường Ngoc Thụy  Thành phốHà Nội
# result: {'province': 'Hà Nội', 'district': 'Long Biên', 'ward': 'Ngọc Thụy'}
# answer {'district': '', 'ward': 'Ngọc Thụy', 'province': 'Hà Nội'}
#
# , Huyện Maỹ Lộc, TỉnhD Nam Định
# result: {'province': 'Nam Định', 'district': '', 'ward': ''}
# answer {'district': 'Mỹ Lộc', 'ward': '', 'province': 'Nam Định'}
#
# TT Qu7 Nhất,,Tỉnh Nam Định
# result: {'province': 'Nam Định', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Quỹ Nhất', 'province': 'Nam Định'}
#
# QX.Tân Hưng Tây, Ph8 Tân,
# result: {'province': 'Long An', 'district': 'Tân Hưng', 'ward': ''}
# answer {'district': 'Phú Tân', 'ward': 'Tân Hưng Tây', 'province': ''}
#
# X.Phong Dụ, , Quảng Ninh
# result: {'province': 'Quảng Ninh', 'district': 'Tiên Yên', 'ward': 'Phong Dụ'}
# answer {'district': '', 'ward': 'Phong Dụ', 'province': 'Quảng Ninh'}
#
# XãPhú Hưng  TBến tre
# result: {'province': 'Bến Tre', 'district': 'Bến Tre', 'ward': 'Phú Hưng'}
# answer {'district': '', 'ward': 'Phú Hưng', 'province': 'Bến Tre'}
#
# XHòa Bqc, HDi Linh,
# result: {'province': 'Lâm Đồng', 'district': 'Di Linh', 'ward': ''}
# answer {'district': 'Di Linh', 'ward': 'Hòa Bắc', 'province': ''}
#
#  Cộng Hòa,,TỉnhHaOi Dương
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Cộng Hòa', 'province': 'Hải Dương'}
#
# X Tân7 Thịnh  Yiên Bái T. yên Bái
# result: {'province': 'Yên Bái', 'district': '', 'ward': ''}
# answer {'district': 'Yên Bái', 'ward': 'Tân Thịnh', 'province': 'Yên Bái'}
#
#  Hải An  Hải Lăng TQdung trị
# result: {'province': 'Hải Phòng', 'district': 'Hải An', 'ward': ''}
# answer {'district': 'Hải Lăng', 'ward': 'Hải An', 'province': 'Quảng Trị'}
#
# Thị trấn Hai Riêng H Sông Hinh
# result: {'province': 'Phú Yên', 'district': 'Sông Hinh', 'ward': 'Hai Riêng'}
# answer {'district': 'Sông Hinh', 'ward': 'Hai Riêng', 'province': ''}
#
# X. Diễn Thành Huyện Diên Châu
# result: {'province': 'Nghệ An', 'district': 'Diễn Châu', 'ward': 'Diễn Thành'}
# answer {'district': 'Diễn Châu', 'ward': 'Diễn Thành', 'province': ''}
#
# ,Bảo Lâ.,Tỉnh Cao Bằng
# result: {'province': 'Cao Bằng', 'district': '', 'ward': ''}
# answer {'district': 'Bảo Lâm', 'ward': '', 'province': 'Cao Bằng'}
#
# X.Chê La,,T.Hà GianZ
# result: {'province': 'Hà Giang', 'district': 'Xín Mần', 'ward': 'Chế Là'}
# answer {'district': '', 'ward': 'Chế Là', 'province': 'Hà Giang'}
#
# Hôno Sỹ  Tỉnh Cao Bằng
# result: {'province': 'Cao Bằng', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Hồng Sỹ', 'province': 'Cao Bằng'}
#
# X. Hành Tín Tây  T.Quảng Ngãi
# result: {'province': 'Quảng Ngãi', 'district': 'Nghĩa Hành', 'ward': 'Hành Tín Tây'}
# answer {'district': '', 'ward': 'Hành Tín Tây', 'province': 'Quảng Ngãi'}
#
#  Hòa Lợi,, Trà vinh
# result: {'province': 'Trà Vinh', 'district': 'Châu Thành', 'ward': 'Hòa Lợi'}
# answer {'district': '', 'ward': 'Hòa Lợi', 'province': 'Trà Vinh'}
#
# Phường Hiệ An, T.X.Kinh Môn, TỉnhHải Dương
# result: {'province': 'Hải Dương', 'district': 'Kinh Môn', 'ward': ''}
# answer {'district': 'Kinh Môn', 'ward': 'Hiệp An', 'province': 'Hải Dương'}
#
# Xã Trịnh Tường H Bát Xát
# result: {'province': 'Lào Cai', 'district': 'Bát Xát', 'ward': 'Trịnh Tường'}
# answer {'district': 'Bát Xát', 'ward': 'Trịnh Tường', 'province': ''}
#
# XãChiềng Mu5ng  T.stn la
# result: {'province': 'Hồ Chí Minh', 'district': '5', 'ward': ''}
# answer {'district': '', 'ward': 'Chiềng Mung', 'province': 'Sơn La'}
#
# P4 T.Ph9ốĐông Hà
# result: {'province': 'Quảng Trị', 'district': 'Đông Hà', 'ward': '4'}
# answer {'district': 'Đông Hà', 'ward': '4', 'province': ''}
#
# F.07, Q6,
# result: {'province': 'Hồ Chí Minh', 'district': '6', 'ward': '7'}
# answer {'district': '6', 'ward': '07', 'province': ''}
#
#  Long Thắng, Huyn Lai ung,
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': 'Lai Vung', 'ward': 'Long Thắng', 'province': ''}
#
#  Bằng Lng,,T.Bắc Kạn
# result: {'province': 'Bắc Kạn', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Bằng Lũng', 'province': 'Bắc Kạn'}
#
# X. Tân An, HuyệnThnh Hà,
# result: {'province': 'Long An', 'district': 'Tân An', 'ward': ''}
# answer {'district': 'Thanh Hà', 'ward': 'Tân An', 'province': ''}
#
# XãtrBung Thanh,,TThanh Hóa
# result: {'province': 'Thanh Hóa', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Trung Thành', 'province': 'Thanh Hóa'}
#
# vĩnh Hưng, , Long An
# result: {'province': 'Long An', 'district': 'Vĩnh Hưng', 'ward': ''}
# answer {'district': '', 'ward': 'Vĩnh Hưng', 'province': 'Long An'}
#
# Phường 04,,Thành phốHồ Chi Minh
# result: {'province': 'Hồ Chí Minh', 'district': '4', 'ward': ''}
# answer {'district': '', 'ward': '04', 'province': 'Hồ Chí Minh'}
#
# Xã Nâm Ntừ  Nậm Pồ
# result: {'province': 'Điện Biên', 'district': 'Nậm Pồ', 'ward': ''}
# answer {'district': 'Nậm Pồ', 'ward': 'Nậm Nhừ', 'province': ''}
#
# X Châu Thuận7  TNghệ An
# result: {'province': 'Nghệ An', 'district': 'Quỳ Châu', 'ward': 'Châu Thuận'}
# answer {'district': '', 'ward': 'Châu Thuận', 'province': 'Nghệ An'}
#
# XNam Cát, HuyệnNam đàn,
# result: {'province': 'Nghệ An', 'district': 'Nam Đàn', 'ward': 'Nam Cát'}
# answer {'district': 'Nam Đàn', 'ward': 'Nam Cát', 'province': ''}
#
# Xã Vị Tân  Vị Than
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': 'Vị Thanh', 'ward': 'Vị Tân', 'province': ''}
#
# X My Thành Bac, HuyệnCai Lậy,
# result: {'province': 'Phú Thọ', 'district': 'Thanh Ba', 'ward': ''}
# answer {'district': 'Cai Lậy', 'ward': 'Mỹ Thành Bắc', 'province': ''}
#
# XCư Drămb H.Krông Bông
# result: {'province': 'Đắk Lắk', 'district': 'Krông Bông', 'ward': 'Cư Drăm'}
# answer {'district': 'Krông Bông', 'ward': 'Cư Drăm', 'province': ''}
#
# X Bình Hi, , T.Quảcg Nam
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Bình Hải', 'province': 'Quảng Nam'}
#
# XãNân Chính, H Ly Nhân, Tỉnh HaNam
# result: {'province': 'Hà Nam', 'district': 'Lý Nhân', 'ward': ''}
# answer {'district': 'Lý Nhân', 'ward': 'Nhân Chính', 'province': 'Hà Nam'}
#
#  Khả cửu, H. Thanh Srn,
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': 'Thanh Sơn', 'ward': 'Khả Cửu', 'province': ''}
#
# Thị Trấn Nông Trường Việt lâm,Vị Xuyen,Ha Giang
# result: {'province': 'Hà Giang', 'district': 'Vị Xuyên', 'ward': 'Việt Lâm'}
# answer {'district': 'Vị Xuyên', 'ward': 'Nông Trường Việt Lâm', 'province': 'Hà Giang'}
#
# , Q11, Hồ Chí Minh
# result: {'province': 'Hồ Chí Minh', 'district': '1', 'ward': ''}
# answer {'district': '11', 'ward': '', 'province': 'Hồ Chí Minh'}
#
# Xã Đông cường, h.Đông Hưng,
# result: {'province': 'Thái Bình', 'district': 'Đông Hưng', 'ward': 'Đông Cường'}
# answer {'district': 'Đông Hưng', 'ward': 'Đông Cường', 'province': ''}
#
# XTrung Nghĩa, , THưng Yên
# result: {'province': 'Hưng Yên', 'district': 'Hưng Yên', 'ward': 'Trung Nghĩa'}
# answer {'district': '', 'ward': 'Trung Nghĩa', 'province': 'Hưng Yên'}
#
# X. Hải Minh,,N5am Định
# result: {'province': 'Nam Định', 'district': 'Hải Hậu', 'ward': 'Hải Minh'}
# answer {'district': '', 'ward': 'Hải Minh', 'province': 'Nam Định'}
#
# X.Đề Thám  T.Lạng Sơn
# result: {'province': 'Lạng Sơn', 'district': 'Tràng Định', 'ward': 'Đề Thám'}
# answer {'district': '', 'ward': 'Đề Thám', 'province': 'Lạng Sơn'}
#
# PhườngHà Mãn, T.X.Thuận Thành,
# result: {'province': 'Bắc Ninh', 'district': 'Thuận Thành', 'ward': 'Hà Mãn'}
# answer {'district': 'Thuận Thành', 'ward': 'Hà Mãn', 'province': ''}
#
# Xa Sơn Thy H. Le Thủy Tỉnh Quảng Bình
# result: {'province': 'Quảng Bình', 'district': 'Lệ Thủy', 'ward': ''}
# answer {'district': 'Lệ Thủy', 'ward': 'Sơn Thủy', 'province': 'Quảng Bình'}
#
#  Đông Htòa Phu Yên
# result: {'province': 'Phú Yên', 'district': '', 'ward': ''}
# answer {'district': 'Đông Hòa', 'ward': '', 'province': 'Phú Yên'}
#
#  Tam Amnh NZm  Núi Thành TQuảng Nam
# result: {'province': 'Quảng Nam', 'district': 'Núi Thành', 'ward': ''}
# answer {'district': 'Núi Thành', 'ward': 'Tam Anh Nam', 'province': 'Quảng Nam'}
#
# X Vân Du, , Phú Thọ
# result: {'province': 'Phú Thọ', 'district': 'Đoan Hùng', 'ward': 'Vân Du'}
# answer {'district': '', 'ward': 'Vân Du', 'province': 'Phú Thọ'}
#
# P. Phong CNốc Th,ị xãQuảng Yên t. Quảng Ninh
# result: {'province': 'Quảng Ninh', 'district': 'Quảng Yên', 'ward': ''}
# answer {'district': 'Quảng Yên', 'ward': 'Phong Cốc', 'province': 'Quảng Ninh'}
#
# X.An Thuận, , TBến Tre
# result: {'province': 'Bến Tre', 'district': 'Thạnh Phú', 'ward': 'An Thuận'}
# answer {'district': '', 'ward': 'An Thuận', 'province': 'Bến Tre'}
#
# Nghi Sơ6n, T.X. Nghi Sơn, Thhanh Hóa
# result: {'province': 'Thanh Hóa', 'district': 'Nghi Sơn', 'ward': ''}
# answer {'district': 'Nghi Sơn', 'ward': 'Nghi Sơn', 'province': 'Thanh Hóa'}
#
# , ThăngFBìh,T. Quảng Nam
# result: {'province': 'Quảng Nam', 'district': '', 'ward': ''}
# answer {'district': 'Thăng Bình', 'ward': '', 'province': 'Quảng Nam'}
#
# TT Đạ Tẻh, , T. Lâm Đồng
# result: {'province': 'Lâm Đồng', 'district': 'Đạ Tẻh', 'ward': ''}
# answer {'district': '', 'ward': 'Đạ Tẻh', 'province': 'Lâm Đồng'}
#
# TT Hội An,,TAn Giang
# result: {'province': 'An Giang', 'district': 'Chợ Mới', 'ward': 'Hội An'}
# answer {'district': '', 'ward': 'Hội An', 'province': 'An Giang'}
#
# X. TErường Thịnh,h Ứng Hòa, Hà Nội
# result: {'province': 'Hà Nội', 'district': 'Ứng Hòa', 'ward': ''}
# answer {'district': 'Ứng Hòa', 'ward': 'Trường Thịnh', 'province': 'Hà Nội'}
#
# X.H Mỗ, Đan PhTượng,
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': 'Đan Phượng', 'ward': 'Hạ Mỗ', 'province': ''}
#
# Xã Quang Tiếns6 Tân Yên,
# result: {'province': 'Bắc Giang', 'district': 'Tân Yên', 'ward': 'Quang Tiến'}
# answer {'district': 'Tân Yên', 'ward': 'Quang Tiến', 'province': ''}
#
# Xã Lương Hòa,HuyệnBen Lức,
# result: {'province': 'Long An', 'district': 'Bến Lức', 'ward': 'Lương Hòa'}
# answer {'district': 'Bến Lức', 'ward': 'Lương Hòa', 'province': ''}
#
# X.Tân Son,hchợ QMới,
# result: {'province': 'Phú Thọ', 'district': 'Tân Sơn', 'ward': ''}
# answer {'district': 'Chợ Mới', 'ward': 'Tân Sơn', 'province': ''}
#
# Quách Phẩm Bắc, , Cà Mzu
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Quách Phẩm Bắc', 'province': 'Cà Mau'}
#
# X Tvực Đạo, , Nam Định
# result: {'province': 'Nam Định', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Trực Đạo', 'province': 'Nam Định'}
#
# Thị trấn Tân Phong, , TThanh Hóa
# result: {'province': 'Thanh Hóa', 'district': 'Quảng Xương', 'ward': 'Tân Phong'}
# answer {'district': '', 'ward': 'Tân Phong', 'province': 'Thanh Hóa'}
#
# X. Lộc Thah,T0P Bảo lộc,TLâm Đông
# result: {'province': 'Lâm Đồng', 'district': 'Bảo Lộc', 'ward': ''}
# answer {'district': 'Bảo Lộc', 'ward': 'Lộc Thanh', 'province': 'Lâm Đồng'}
#
# X Đương Hoa  TQuảng Ninh
# result: {'province': 'Quảng Ninh', 'district': 'Hải Hà', 'ward': 'Đường Hoa'}
# answer {'district': '', 'ward': 'Đường Hoa', 'province': 'Quảng Ninh'}
#
# XMiền Đồi,LaZc Sơn,
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': 'Lạc Sơn', 'ward': 'Miền Đồi', 'province': ''}
#
# X Phu Mãn   HN
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Phú Mãn', 'province': 'Hà Nội'}
#
# XTâm Thsắng Cư Jút TỉnhĐắk Nông
# result: {'province': 'Đắk Nông', 'district': 'Cư Jút', 'ward': ''}
# answer {'district': 'Cư Jút', 'ward': 'Tâm Thắng', 'province': 'Đắk Nông'}
#
# XLa Sơn H. Binh lục
# result: {'province': 'Hà Nam', 'district': 'Bình Lục', 'ward': 'La Sơn'}
# answer {'district': 'Bình Lục', 'ward': 'La Sơn', 'province': ''}
#
# F. Điện Nam Bắc, x TQuảng Nam
# result: {'province': 'Quảng Nam', 'district': 'Đông Giang', 'ward': 'Ba'}
# answer {'district': '', 'ward': 'Điện Nam Bắc', 'province': 'Quảng Nam'}
#
# Bình Sa HuyệnThăng Bình
# result: {'province': 'Quảng Nam', 'district': 'Thăng Bình', 'ward': 'Bình Sa'}
# answer {'district': 'Thăng Bình', 'ward': 'Bình Sa', 'province': ''}
#
# Tinh Nhu Huyện Thanh Sơn Tỉnh Phú Tho
# result: {'province': 'Phú Thọ', 'district': 'Thanh Sơn', 'ward': ''}
# answer {'district': 'Thanh Sơn', 'ward': 'Tinh Nhuệ', 'province': 'Phú Thọ'}
#
# XãGia Vượng, Gia Viễn,
# result: {'province': 'Ninh Bình', 'district': 'Gia Viễn', 'ward': 'Gia Vượng'}
# answer {'district': 'Gia Viễn', 'ward': 'Gia Vượng', 'province': ''}
#
#  Hợp đức, , Tp Hải Phòng
# result: {'province': 'Hải Phòng', 'district': 'Đồ Sơn', 'ward': 'Hợp Đức'}
# answer {'district': '', 'ward': 'Hợp Đức', 'province': 'Hải Phòng'}
#
# Thị trấnSông Đốc, , TnhCà Mau
# result: {'province': 'Cà Mau', 'district': 'Trần Văn Thời', 'ward': 'Sông Đốc'}
# answer {'district': '', 'ward': 'Sông Đốc', 'province': 'Cà Mau'}
#
# X.Yên Phong  Tỉnh Bắc Kạn
# result: {'province': 'Bắc Kạn', 'district': 'Chợ Đồn', 'ward': 'Yên Phong'}
# answer {'district': '', 'ward': 'Yên Phong', 'province': 'Bắc Kạn'}
#
# P. Nhi Thu Thị xã Cửa Lò TNghệ An
# result: {'province': 'Nghệ An', 'district': 'Cửa Lò', 'ward': ''}
# answer {'district': 'Cửa Lò', 'ward': 'Nghi Thu', 'province': 'Nghệ An'}
#
#  Ea Huar,HuyệnBuôn Đôn,
# result: {'province': 'Đắk Lắk', 'district': 'Buôn Đôn', 'ward': 'Ea Huar'}
# answer {'district': 'Buôn Đôn', 'ward': 'Ea Huar', 'province': ''}
#
# X Tân Thanh Huyện Lang Giang
# result: {'province': 'Bắc Giang', 'district': 'Lạng Giang', 'ward': 'Tân Thanh'}
# answer {'district': 'Lạng Giang', 'ward': 'Tân Thanh', 'province': ''}
#
# X. Sơn Hv HSơn Hoa Tỉnh Phú Yên
# result: {'province': 'Phú Yên', 'district': 'Sơn Hòa', 'ward': ''}
# answer {'district': 'Sơn Hòa', 'ward': 'Sơn Hội', 'province': 'Phú Yên'}
#
# Xã Bản My H..Hoàng Su Phì T.Hà Giang
# result: {'province': 'Hà Giang', 'district': 'Hoàng Su Phì', 'ward': ''}
# answer {'district': 'Hoàng Su Phì', 'ward': 'Bản Máy', 'province': 'Hà Giang'}
#
# Công Hòa H.Kim Thành
# result: {'province': 'Hải Dương', 'district': 'Kim Thành', 'ward': 'Cộng Hòa'}
# answer {'district': 'Kim Thành', 'ward': 'Cộng Hòa', 'province': ''}
#
#  H.Văn Giang Tỉnh Hưng Yê0
# result: {'province': 'An Giang', 'district': '', 'ward': ''}
# answer {'district': 'Văn Giang', 'ward': '', 'province': 'Hưng Yên'}
#
#  eăn Tiến, Yên Lạc, vĩnh P0húc
# result: {'province': 'Vĩnh Phúc', 'district': 'Yên Lạc', 'ward': ''}
# answer {'district': 'Yên Lạc', 'ward': 'Văn Tiến', 'province': 'Vĩnh Phúc'}
#
# X.Cẩm Hoàng,,T. Hải Dươnwg
# result: {'province': 'Hải Dương', 'district': 'Cẩm Giàng', 'ward': 'Cẩm Hoàng'}
# answer {'district': '', 'ward': 'Cẩm Hoàng', 'province': 'Hải Dương'}
#
# X. Cat Chánh,HuyệnPhù Cát,
# result: {'province': 'Bình Định', 'district': 'Phù Cát', 'ward': 'Cát Chánh'}
# answer {'district': 'Phù Cát', 'ward': 'Cát Chánh', 'province': ''}
#
# Xthịnh Vượng,A , TG.Cao băng
# result: {'province': 'Cao Bằng', 'district': 'Nguyên Bình', 'ward': 'Thịnh Vượng'}
# answer {'district': '', 'ward': 'Thịnh Vượng', 'province': 'Cao Bằng'}
#
# Diên Thạnh,,T Khabnh Hòa
# result: {'province': '', 'district': '', 'ward': ''}
# answer {'district': '', 'ward': 'Diên Thạnh', 'province': 'Khánh Hòa'}
#
# X.Việt Hồng, , TrHà Giang
# result: {'province': 'Hà Giang', 'district': 'Bắc Quang', 'ward': 'Việt Hồng'}
# answer {'district': '', 'ward': 'Việt Hồng', 'province': 'Hà Giang'}
#
# X.Đức Sơn Anh Sơn
# result: {'province': 'Nghệ An', 'district': 'Anh Sơn', 'ward': 'Đức Sơn'}
# answer {'district': 'Anh Sơn', 'ward': 'Đức Sơn', 'province': ''}
#
# Đứ Lợi,H Mộ Đức,TỉnhQuản Ngãi
# result: {'province': 'Quảng Ngãi', 'district': 'Mộ Đức', 'ward': ''}
# answer {'district': 'Mộ Đức', 'ward': 'Đức Lợi', 'province': 'Quảng Ngãi'}
#
# X Song Lộc H.Châu Thành
# result: {'province': 'Vĩnh Phúc', 'district': 'Sông Lô', 'ward': ''}
# answer {'district': 'Châu Thành', 'ward': 'Song Lộc', 'province': ''}
#
# X. Bản Nguyen,HuyệnLâm Thao,
# result: {'province': 'Phú Thọ', 'district': 'Lâm Thao', 'ward': 'Bản Nguyên'}
# answer {'district': 'Lâm Thao', 'ward': 'Bản Nguyên', 'province': ''}
#
# XThạch Xuâ,Thạch Hà,T. Hà Tĩnh
# result: {'province': 'Hà Tĩnh', 'district': 'Thạch Hà', 'ward': ''}
# answer {'district': 'Thạch Hà', 'ward': 'Thạch Xuân', 'province': 'Hà Tĩnh'}
#
# XDuy Hải  TQuảng Nam
# result: {'province': 'Quảng Nam', 'district': 'Duy Xuyên', 'ward': 'Duy Hải'}
# answer {'district': '', 'ward': 'Duy Hải', 'province': 'Quảng Nam'}
#
# x. Văn Cẩs HuyệnHung Hà Tthái Bình
# result: {'province': 'Thái Bình', 'district': 'Hưng Hà', 'ward': ''}
# answer {'district': 'Hưng Hà', 'ward': 'Văn Cẩm', 'province': 'Thái Bình'}
#
# oã Bnh Ngọc,T.Phố Tuy Hoà,Tỉnhphú Yên
# result: {'province': 'Phú Yên', 'district': 'Tuy Hoà', 'ward': ''}
# answer {'district': 'Tuy Hoà', 'ward': 'Bình Ngọc', 'province': 'Phú Yên'}
#
#  Chương Dương, HuyệnĐôngHưng,
# result: {'province': 'Thái Bình', 'district': 'Đông Hưng', 'ward': 'Chương Dương'}
# answer {'district': 'Đông Hưng', 'ward': 'Chương Dương', 'province': ''}
#
# Nậm Tin  Diện Biên
# result: {'province': 'Điện Biên', 'district': 'Nậm Pồ', 'ward': 'Nậm Tin'}
# answer {'district': '', 'ward': 'Nậm Tin', 'province': 'Điện Biên'}
#
#  T.P Phan Rang-Tháp lhàm  Ninh Thuận
# result: {'province': 'Ninh Thuận', 'district': '', 'ward': ''}
# answer {'district': 'Phan Rang-Tháp Chàm', 'ward': '', 'province': 'Ninh Thuận'}
#
# , Tân Phươc, Tin GJiang
# result: {'province': 'Đồng Nai', 'district': 'Tân Phú', 'ward': ''}
# answer {'district': 'Tân Phước', 'ward': '', 'province': 'Tiền Giang'}
#
# XTrung Kiên,,Tỉnh Vĩnh Phuúc
# result: {'province': 'Nghệ An', 'district': 'Vinh', 'ward': ''}
# answer {'district': '', 'ward': 'Trung Kiên', 'province': 'Vĩnh Phúc'}
#
#  Đức Lĩnh,Vũ Quang,
# result: {'province': 'Hà Tĩnh', 'district': 'Vũ Quang', 'ward': 'Đức Lĩnh'}
# answer {'district': 'Vũ Quang', 'ward': 'Đức Lĩnh', 'province': ''}
#
#  Yn phú, HBắc Mê, TỉnhV Hà giang
# result: {'province': 'Hà Giang', 'district': 'Bắc Mê', 'ward': ''}
# answer {'district': 'Bắc Mê', 'ward': 'Yên Phú', 'province': 'Hà Giang'}
#
# Xuân Tân t.P Long Khánh
# result: {'province': 'Đồng Nai', 'district': 'Long Khánh', 'ward': 'Xuân Tân'}
# answer {'district': 'Long Khánh', 'ward': 'Xuân Tân', 'province': ''}
#
# Phú Đô HuyệnPhú Lươnz
# result: {'province': 'Thái Nguyên', 'district': 'Phú Lương', 'ward': 'Phú Đô'}
# answer {'district': 'Phú Lương', 'ward': 'Phú Đô', 'province': ''}
#
#  Thái Ha, HBa Vì, T.pHNội
# result: {'province': 'Hà Nội', 'district': 'Ba Vì', 'ward': ''}
# answer {'district': 'Ba Vì', 'ward': 'Thái Hòa', 'province': 'Hà Nội'}
#
# X.Phước Hiệp  Tỉnh Bến Tre
# result: {'province': 'Bến Tre', 'district': 'Mỏ Cày Nam', 'ward': 'Phước Hiệp'}
# answer {'district': '', 'ward': 'Phước Hiệp', 'province': 'Bến Tre'}
#
#  bản HoJn huyện Tam Đường Tỉnh Lai Châu
# result: {'province': 'Lai Châu', 'district': 'Tam Đường', 'ward': ''}
# answer {'district': 'Tam Đường', 'ward': 'Bản Hon', 'province': 'Lai Châu'}
#
# X. Thanh Phongjc , Tỉnhthanh hóa
# result: {'province': 'Thanh Hóa', 'district': 'Như Xuân', 'ward': 'Thanh Phong'}
# answer {'district': '', 'ward': 'Thanh Phong', 'province': 'Thanh Hóa'}
#
# xã Bình Trung,,TLạng Son
# result: {'province': 'Lạng Sơn', 'district': 'Cao Lộc', 'ward': 'Bình Trung'}
# answer {'district': '', 'ward': 'Bình Trung', 'province': 'Lạng Sơn'}
#
# P Thủy Châu,T.X. hươngThủy,Thừa.t.Huế
# result: {'province': 'Thừa Thiên Huế', 'district': 'Huế', 'ward': ''}
# answer {'district': 'Hương Thủy', 'ward': 'Thủy Châu', 'province': 'Thừa Thiên Huế'}
#
# Thi trấ Ea. Knốp,H. Ea Kar,
# result: {'province': 'Đắk Lắk', 'district': 'Ea Kar', 'ward': 'Ea Knốp'}
# answer {'district': 'Ea Kar', 'ward': 'Ea Knốp', 'province': ''}
#
# X.Nga Thanh hyện Nga son TỉnhThanhQ Hóa
# result: {'province': 'Thanh Hóa', 'district': 'Nga Sơn', 'ward': 'Nga Thành'}
# answer {'district': 'Nga Sơn', 'ward': 'Nga Thanh', 'province': 'Thanh Hóa'}
#
# F Tân bình  dĩ An
# result: {'province': 'Bình Dương', 'district': 'Dĩ An', 'ward': 'An Bình'}
# answer {'district': 'Dĩ An', 'ward': 'Tân Bình', 'province': ''}
#
# x2Trung Sơn,,TỉnhNghê An
# result: {'province': 'Nghệ An', 'district': 'Đô Lương', 'ward': 'Trung Sơn'}
# answer {'district': '', 'ward': 'Trung Sơn', 'province': 'Nghệ An'}
#
# Total pass: 280
